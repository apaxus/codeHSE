# %% [markdown]
# <a href="https://colab.research.google.com/github/apaxus/codeHSE/blob/main/Swot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Группа: 20БИ-3')
print('ФИО: Сесекин Александр Георгиевич')
# !ln -fs /usr/share/zoneinfo/Europe/Moscow /etc/localtime
# !date

# %%
# !pip install --upgrade gspread
import gspread
from google.colab import drive
drive.mount('/content/drive')
import os
print(os.getcwd())
print(os.listdir('./'))
print(os.listdir('/content/drive'))
print(os.listdir('/content/drive/MyDrive/help'))

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРабота с таблицей')
# %ll -lAF /content/drive/MyDrive/"Colab Notebooks"/help/
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/help/swot.gsheet')
table = gs.open_by_key('1hU3KYIXVoq57fQQidqp4NnhA-CpocRc38CY7ceYvN0E')
print(dir(table))
worksheet = table.worksheet('List1')
rows = worksheet.get_all_values()
print(rows)
strength = [0] * 6
s=0
opportunities = [0] * 6
o = 0
weakness = [0] * 6
w = 0
threats = [0] * 6
t = 0
flag = 'strength'
for i in rows:
  if i[0] == 'strength':
    flag = 'strength'
  if i[0] == 'weakness':
    flag = 'weakness'
  if i[0] == 'opportunities':
    flag = 'opportunities'
  if i[0] == 'threats':
    flag = 'threats'
  if flag == 'strength' and i[4] != '' and i[4] != 'power':
    strength[s] = i[4]
    s = s + 1
  if flag == 'opportunities' and i[4] != '' and i[4] != 'power':
    opportunities[o] = i[4]
    o = o + 1
  if flag == 'weakness' and i[4] != '' and i[4] != 'power':
    weakness[w] = i[4]
    w = w + 1
  if flag == 'threats' and i[4] != '' and i[4] != 'power':
    threats[t] = i[4]
    t = t + 1
print(strength)
print(opportunities)
print(weakness)
print(threats)
streng = 0
opport = 0
weak = 0
threat = 0
for i in strength:
  streng = streng + float(i)
for i in opportunities:
  opport = opport + float(i)
for i in weakness:
  weak = weak + float(i)
for i in threats:
  threat = threat + float(i)
worksheet.update('A43', 'strength ' + str(s))
worksheet.update('B43', 'weakness ' + str(w))
worksheet.update('C43', 'opportunities ' + str(o))
worksheet.update('D43', 'threats ' + str(t))
worksheet.update('A44', 'sum power ' + str(s + o - w - t))
prob = (s + o) / (s + o + w + t)
worksheet.update('B44', 'Probability of good result ' + str(prob))
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.2)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
#
# Работа с таблицей
# total 48
# -rw------- 1 root 12017 Mar  4 00:18 bu.png
# -rw------- 1 root   151 Mar  4 00:18 swot.gsheet
# -rw------- 1 root 36167 Mar  4 00:18 Swot.ipynb
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# [['', 'Бар-клуб', '', '', ''], ['strenghth', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['Выгодное расположение заведения.', 'Заведение находится в центре города, где его удобно найти', '9', '0.7', '6.3'], ['Сервис в заведении построен для удобства посетителей.', 'Свои столики, барная стойка, диджей, танцпол, личный официант и кальянщик обеспечат комфорт заведению', '8', '0.8', '6.4'], ['Высокий уровень обслуживания.', 'Ответственные и вежливые к гостям официанты', '7', '0.9', '6.3'], ['Доступные цены и дисконтные карты постоянных посетителей', 'Возможность получения персональных скидок, которые будут стимулировать дальнейшее посещение заведения.', '7', '1', '7'], ['weakness', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['Высокая арендная плата, обусловленная местоположением.', 'Попросить скидку взамен на своевременную оплату без долгов и задержек', '8', '1', '8'], ['Значительная нагрузка на одного специалиста.', 'Увеличение числа персонала', '5', '0.7', '3.5'], ['Нестабильные объемы реализации.', 'Ввод рекламы, когда падает выручка (сезонно)', '6', '0.7', '4.2'], ['Наблюдается текучесть кадров среди официантов и барменов, что обуславливается полной занятостью', 'Предоставить возможность гибкого графика', '6', '0.8', '4.8'], ['opportunities', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['Более активное использование рекламы, для привлечения большего числа посетителей.', 'Будем рекламировать себя через социальные сети', '4', '1', '4'], ['Возможность обучения и повышения квалификации обслуживающего персонала', 'Даст возможность карьерного роста персонала.', '5', '0.9', '4.5'], ['Систему премирования официантов и барменов', 'Возможность дополнительные успехи за персональные достижения', '5', '0.8', '4'], ['Возможность увеличения количества поставщиков', 'Расширение меню для поддержания клиентной базы', '7', '0.7', '4.9'], ['threats', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['Активная конкуренция.', 'Занимать лидирующую позицию среди конкурентов в районе своих поситителей', '8', '0.9', '7.2'], ['Неадекватность некоторых гостей.', 'Усилинный фейс-контроль', '7', '0.9', '6.3'], ['Бар стоит очень дорого', 'Персональный охранник у барного стола', '5', '1', '5'], ['Коронавирус', '', '2', '0.4', '0.8'], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['strength 4', 'weakness 4', 'opportunities 4', 'threats 4', ''], ['sum power 0', 'Probability of good result 0.5', '', '', '']]
# ['6.3', '6.4', '6.3', '7', 0, 0]
# ['4', '4.5', '4', '4.9', 0, 0]
# ['8', '3.5', '4.2', '4.8', 0, 0]
# ['7.2', '6.3', '5', '0.8', 0, 0]
# {'spreadsheetId': '1hU3KYIXVoq57fQQidqp4NnhA-CpocRc38CY7ceYvN0E',
#  'updatedCells': 1,
#  'updatedColumns': 1,
#  'updatedRange': 'List1!B44',
#  'updatedRows': 1}

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/help Notebooks/project
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/help/swot.gsheet')
table = gs.open_by_key('1hU3KYIXVoq57fQQidqp4NnhA-CpocRc38CY7ceYvN0E')
print(dir(table))
worksheet = table.worksheet('List1')
rows = worksheet.get_all_values()
print(rows)
strength = [0] * 6
s = 0
opportunities = [0] * 6
o = 0
weakness = [0] * 6
w = 0
threats = [0] * 6
t = 0
flag = 'strength'
for i in rows:
  if i[0] == 'strength':
    flag = 'strength'
  if i[0] == 'weakness':
    flag = 'weakness'
  if i[0] == 'opportunities':
    flag = 'opportunities'
  if i[0] == 'threats':
    flag = 'threats'
  if flag == 'strength' and i[4] != '' and i[4] != 'power':
    strength[s] = i[4]
    s = s + 1
  if flag == 'opportunities' and i[4] != '' and i[4] != 'power':
    opportunities[o] = i[4]
    o = o + 1
  if flag == 'weakness' and i[4] != '' and i[4] != 'power':
    weakness[w] = i[4]
    w = w + 1
  if flag == 'threats' and i[4] != '' and i[4] != 'power':
    threats[t] = i[4]
    t = t + 1
print(strength)
print(opportunities)
print(weakness)
print(threats)
streng = 0
opport = 0
weak = 0
threat = 0
for i in strength:
  streng = streng + float(i)
for i in opportunities:
  opport = opport + float(i)
for i in weakness:
  weak = weak + float(i)
for i in threats:
  threat = threat + float(i)
  import matplotlib.pyplot as plt
x=list()
x_float=list()
title=list()
y_float=list()
    
title = [ "strengths", "weaknesses", "opportunities", "threats", "result"]
x=title
x_float = [1, 2, 3, 4, 5]
result = streng - 1*weak + opport - 1*threat
y = [streng, weak, opport, threat]
y_float = [streng, -1*weak, opport, -1*threat,  result]
print(x_float,title,y_float)
print('списки формированы-->\n')
x_pos=list()
for i in range(x_float.__len__()):
    x_pos.append(i)
print('<!--разбивка по абсцисс и значения ординат\n', len( x_float), x_pos, y_float, ' -->\n')

fig=plt.figure(figsize=(8,6), dpi=72)
plt.bar(x_pos, y_float, width=0.75, align='edge', alpha=0.4)
plt.xticks(x_pos,  x_float, fontsize=14)
plt.xlabel('Обозначения', fontsize=14)
plt.ylabel('Мощность воздействия', fontsize=14)
plt.title('SWOT', fontsize=14)
plt.grid(True, color='r', linestyle='-', linewidth=2)
#plt.draw()
plt.show()
fig.savefig("/content/drive/MyDrive/Colab Notebooks/help/bu.png")
print('<div class="d-flex flex-row ">')
print('<div class="card m-1" style="width: 28rem;">',
      '<img  src="/content/drive/MyDrive/Colab Notebooks/help/bu.png" class="card-img-top" alt="...">',
      '<div class="card-body">')
    
for i in range(title.__len__()):
    print(i+1, " - ", title[i], "; ")
    i += 1
print('</div>', '</div>')
print('<div>')
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/help': No such file or directory
# ls: cannot access 'Notebooks/project': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# [['', 'Бар-клуб', '', '', ''], ['strenghth', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['Выгодное расположение заведения.', 'Заведение находится в центре города, где его удобно найти', '9', '0.7', '6.3'], ['Сервис в заведении построен для удобства посетителей.', 'Свои столики, барная стойка, диджей, танцпол, личный официант и кальянщик обеспечат комфорт заведению', '8', '0.8', '6.4'], ['Высокий уровень обслуживания.', 'Ответственные и вежливые к гостям официанты', '7', '0.9', '6.3'], ['Доступные цены и дисконтные карты постоянных посетителей', 'Возможность получения персональных скидок, которые будут стимулировать дальнейшее посещение заведения.', '7', '1', '7'], ['weakness', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['Высокая арендная плата, обусловленная местоположением.', 'Попросить скидку взамен на своевременную оплату без долгов и задержек', '8', '1', '8'], ['Значительная нагрузка на одного специалиста.', 'Увеличение числа персонала', '5', '0.7', '3.5'], ['Нестабильные объемы реализации.', 'Ввод рекламы, когда падает выручка (сезонно)', '6', '0.7', '4.2'], ['Наблюдается текучесть кадров среди официантов и барменов, что обуславливается полной занятостью', 'Предоставить возможность гибкого графика', '6', '0.8', '4.8'], ['opportunities', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['Более активное использование рекламы, для привлечения большего числа посетителей.', 'Будем рекламировать себя через социальные сети', '4', '1', '4'], ['Возможность обучения и повышения квалификации обслуживающего персонала', 'Даст возможность карьерного роста персонала.', '5', '0.9', '4.5'], ['Систему премирования официантов и барменов', 'Возможность дополнительные успехи за персональные достижения', '5', '0.8', '4'], ['Возможность увеличения количества поставщиков', 'Расширение меню для поддержания клиентной базы', '7', '0.7', '4.9'], ['threats', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['Активная конкуренция.', 'Занимать лидирующую позицию среди конкурентов в районе своих поситителей', '8', '0.9', '7.2'], ['Неадекватность некоторых гостей.', 'Усилинный фейс-контроль', '7', '0.9', '6.3'], ['Бар стоит очень дорого', 'Персональный охранник у барного стола', '5', '1', '5'], ['Коронавирус', '', '2', '0.4', '0.8'], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['strength 4', 'weakness 4', 'opportunities 4', 'threats 4', ''], ['sum power 0', 'Probability of good result 0.5', '', '', '']]
# ['6.3', '6.4', '6.3', '7', 0, 0]
# ['4', '4.5', '4', '4.9', 0, 0]
# ['8', '3.5', '4.2', '4.8', 0, 0]
# ['7.2', '6.3', '5', '0.8', 0, 0]
# [1, 2, 3, 4, 5] ['strengths', 'weaknesses', 'opportunities', 'threats', 'result'] [26.0, -20.5, 17.4, -19.3, 3.599999999999998]
# списки формированы-->
#
# <!--разбивка по абсцисс и значения ординат
#  5 [0, 1, 2, 3, 4] [26.0, -20.5, 17.4, -19.3, 3.599999999999998]  -->
# <div class="d-flex flex-row ">
# <div class="card m-1" style="width: 28rem;"> <img  src="/content/drive/MyDrive/Colab Notebooks/help/bu.png" class="card-img-top" alt="..."> <div class="card-body">
# 1  -  strengths ;
# 2  -  weaknesses ;
# 3  -  opportunities ;
# 4  -  threats ;
# 5  -  result ;
# </div> </div>
# <div>

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/help
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/help/swot.gsheet')
table = gs.open_by_key('1hU3KYIXVoq57fQQidqp4NnhA-CpocRc38CY7ceYvN0E')
print(dir(table))
worksheet = table.worksheet('strenghth')
rows = worksheet.get_all_values()
name = list()
actions = list()
importance = list()
probability = list()
power = list()
power_sh = list()
power_raw = list()
i=0
for row in rows:
  if(i>0):
    print (i, row)
    name.append(row[0])
    importance.append(int(row[2]))
    probability.append(float(row[3]))
    power.append(int(row[2])*float(row[3]))
    power_raw = list()
    power_raw.append(int(row[2])*float(row[3]))
    power_sh.append(power_raw)
  i+=1
print(power_sh)
worksheet.update('E2:E10', power_sh)
result = sum(power)
worksheet.update('G3','Суммарная power:')
worksheet.update('H3',result)
print('Суммарная Power strengths составляет:', result)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

i=0
line= list()
cols=worksheet.col_values(1)
for col in cols:
  if (i>0):
    line.append(i)
  i+=1

powers = power
x = np.arange(len(line))  
width = 0.6  
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, powers, width)
a=worksheet.col_values(1)
ax.set_ylabel('Мощность воздействия')
ax.set_title('Strengths')
ax.set_xlabel('Обозначения')
ax.set_xticks(x)
ax.set_xticklabels(line)
fig.tight_layout()
plt.show()
k=0

for col in cols:
  if(k>0):
    print (k,'- ', col)
  k+=1
# !date
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/help': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# 1 ['Выгодное расположение заведения.', 'Заведение находится в центре города, где его удобно найти', '9', '0.7', '6.3', '', '', '']
# 2 ['Сервис в заведении построен для удобства посетителей.', 'Свои столики, барная стойка, диджей, танцпол, личный официант и кальянщик обеспечат комфорт заведению', '8', '0.8', '6.4', '', 'Суммарная power:', '26']
# 3 ['Высокий уровень обслуживания.', 'Ответственные и вежливые к гостям официанты', '7', '0.9', '6.3', '', '', '']
# 4 ['Доступные цены и дисконтные карты постоянных посетителей', 'Возможность получения персональных скидок, которые будут стимулировать дальнейшее посещение заведения.', '7', '1', '7', '', '', '']
# [[6.3], [6.4], [6.3], [7.0]]
# Суммарная Power strengths составляет: 26.0
# 1 -  Выгодное расположение заведения.
# 2 -  Сервис в заведении построен для удобства посетителей.
# 3 -  Высокий уровень обслуживания.
# 4 -  Доступные цены и дисконтные карты постоянных посетителей
# Mon Mar 15 21:46:28 UTC 2021

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/help
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/help/swot.gsheet')
table = gs.open_by_key('1hU3KYIXVoq57fQQidqp4NnhA-CpocRc38CY7ceYvN0E')
print(dir(table))
worksheet = table.worksheet('weakness')
rows = worksheet.get_all_values()
name = list()
actions = list()
importance = list()
probability = list()
power = list()
power_sh = list()
power_raw = list()
i=0
for row in rows:
  if(i>0):
    print (i, row)
    name.append(row[0])
    importance.append(int(row[2]))
    probability.append(float(row[3]))
    power.append(int(row[2])*float(row[3]))
    power_raw = list()
    power_raw.append(int(row[2])*float(row[3]))
    power_sh.append(power_raw)
  i+=1
print(power_sh)
worksheet.update('E2:E10', power_sh)
result = sum(power)
worksheet.update('G3','Суммарная power:')
worksheet.update('H3',result)
print('Суммарная Power weakness составляет:', result)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

i=0
line= list()
cols=worksheet.col_values(1)
for col in cols:
  if (i>0):
    line.append(i)
  i+=1

powers = power
x = np.arange(len(line))  
width = 0.6  
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, powers, width)
a=worksheet.col_values(1)
ax.set_ylabel('Мощность воздействия')
ax.set_title('Weakness')
ax.set_xlabel('Обозначения')
ax.set_xticks(x)
ax.set_xticklabels(line)
fig.tight_layout()
plt.show()
k=0

for col in cols:
  if(k>0):
    print (k,'- ', col)
  k+=1
# !date
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/help': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# 1 ['Высокая арендная плата, обусловленная местоположением.', 'Попросить скидку взамен на своевременную оплату без долгов и задержек', '8', '1', '8', '', '', '', '']
# 2 ['Значительная нагрузка на одного специалиста.', 'Увеличение числа персонала', '5', '0.7', '3.5', '', 'Суммарная power:', '20.5', '20.5']
# 3 ['Нестабильные объемы реализации.', 'Ввод рекламы, когда падает выручка (сезонно)', '6', '0.7', '4.2', '', '', '', '']
# 4 ['Наблюдается текучесть кадров среди официантов и барменов, что обуславливается полной занятостью', 'Предоставить возможность гибкого графика', '6', '0.8', '4.8', '', '', '', '']
# [[8.0], [3.5], [4.199999999999999], [4.800000000000001]]
# Суммарная Power weakness составляет: 20.5
# 1 -  Высокая арендная плата, обусловленная местоположением.
# 2 -  Значительная нагрузка на одного специалиста.
# 3 -  Нестабильные объемы реализации.
# 4 -  Наблюдается текучесть кадров среди официантов и барменов, что обуславливается полной занятостью
# Mon Mar 15 21:13:45 UTC 2021

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/help
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/help/swot.gsheet')
table = gs.open_by_key('1hU3KYIXVoq57fQQidqp4NnhA-CpocRc38CY7ceYvN0E')
print(dir(table))
worksheet = table.worksheet('opportunities')
rows = worksheet.get_all_values()
name = list()
actions = list()
importance = list()
probability = list()
power = list()
power_sh = list()
power_raw = list()
i=0
for row in rows:
  if(i>0):
    print (i, row)
    name.append(row[0])
    importance.append(int(row[2]))
    probability.append(float(row[3]))
    power.append(int(row[2])*float(row[3]))
    power_raw = list()
    power_raw.append(int(row[2])*float(row[3]))
    power_sh.append(power_raw)
  i+=1
print(power_sh)
worksheet.update('E2:E10', power_sh)
result = sum(power)
worksheet.update('G3','Суммарная power:')
worksheet.update('H3',result)
print('Суммарная Power opportunities составляет:', result)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

i=0
line= list()
cols=worksheet.col_values(1)
for col in cols:
  if (i>0):
    line.append(i)
  i+=1

powers = power
x = np.arange(len(line))  
width = 0.6  
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, powers, width)
a=worksheet.col_values(1)
ax.set_ylabel('Мощность воздействия')
ax.set_title('Opprtunities')
ax.set_xlabel('Обозначения')
ax.set_xticks(x)
ax.set_xticklabels(line)
fig.tight_layout()
plt.show()
k=0

for col in cols:
  if(k>0):
    print (k,'- ', col)
  k+=1
# !date
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/help': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# 1 ['Более активное использование рекламы, для привлечения большего числа посетителей.', 'Будем рекламировать себя через социальные сети', '4', '1', '4', '', '', '']
# 2 ['Возможность обучения и повышения квалификации обслуживающего персонала', 'Даст возможность карьерного роста персонала.', '5', '0.9', '4.5', '', 'Суммарная power:', '17.4']
# 3 ['Систему премирования официантов и барменов', 'Возможность дополнительные успехи за персональные достижения', '5', '0.8', '4', '', '', '']
# 4 ['Возможность увеличения количества поставщиков', 'Расширение меню для поддержания клиентной базы', '7', '0.7', '4.9', '', '', '']
# [[4.0], [4.5], [4.0], [4.8999999999999995]]
# Суммарная Power opportunities составляет: 17.4
# 1 -  Более активное использование рекламы, для привлечения большего числа посетителей.
# 2 -  Возможность обучения и повышения квалификации обслуживающего персонала
# 3 -  Систему премирования официантов и барменов
# 4 -  Возможность увеличения количества поставщиков
# Mon Mar 15 21:14:02 UTC 2021

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/help
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/help/swot.gsheet')
table = gs.open_by_key('1hU3KYIXVoq57fQQidqp4NnhA-CpocRc38CY7ceYvN0E')
print(dir(table))
worksheet = table.worksheet('threats')
rows = worksheet.get_all_values()
name = list()
actions = list()
importance = list()
probability = list()
power = list()
power_sh = list()
power_raw = list()
i=0
for row in rows:
  if(i>0):
    print (i, row)
    name.append(row[0])
    importance.append(int(row[2]))
    probability.append(float(row[3]))
    power.append(int(row[2])*float(row[3]))
    power_raw = list()
    power_raw.append(int(row[2])*float(row[3]))
    power_sh.append(power_raw)
  i+=1
print(power_sh)
worksheet.update('E2:E10', power_sh)
result = sum(power)
worksheet.update('G3','Суммарная power:')
worksheet.update('H3',result)
print('Суммарная Power threats составляет:', result)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

i=0
line= list()
cols=worksheet.col_values(1)
for col in cols:
  if (i>0):
    line.append(i)
  i+=1

powers = power
x = np.arange(len(line)) 
width = 0.6  
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, powers, width)
a=worksheet.col_values(1)
ax.set_ylabel('Мощность воздействия')
ax.set_title('Threats')
ax.set_xlabel('Обозначения')
ax.set_xticks(x)
ax.set_xticklabels(line)
fig.tight_layout()
plt.show()
k=0

for col in cols:
  if(k>0):
    print (k,'- ', col)
  k+=1
# !date
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/help': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# 1 ['Активная конкуренция.', 'Занимать лидирующую позицию среди конкурентов в районе своих поситителей', '8', '0.9', '7.2', '', '', '']
# 2 ['Неадекватность некоторых гостей.', 'Усилинный фейс-контроль', '7', '0.9', '6.3', '', 'Суммарная power:', '19.3']
# 3 ['Бар стоит очень дорого', 'Персональный охранник у барного стола', '5', '1', '5', '', '', '']
# 4 ['Коронавирус', '', '2', '0.4', '0.8', '', '', '']
# [[7.2], [6.3], [5.0], [0.8]]
# Суммарная Power threats составляет: 19.3
# 1 -  Активная конкуренция.
# 2 -  Неадекватность некоторых гостей.
# 3 -  Бар стоит очень дорого
# 4 -  Коронавирус
# Mon Mar 15 21:10:36 UTC 2021
